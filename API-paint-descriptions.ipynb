# %%
# search for purple

headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:126.0) Gecko/20100101 Firefox/126.0',
    'Accept': 'application/json, text/plain, */*',
    'Accept-Language': 'en-US,en;q=0.5',
    # 'Accept-Encoding': 'gzip, deflate, br, zstd',
    'Ocp-Apim-Subscription-Key': '48c3c3e75b424f97904f9659da65b4d0',
    'Origin': 'https://www.benjaminmoore.com',
    'Connection': 'keep-alive',
    'Referer': 'https://www.benjaminmoore.com/',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'cross-site',
    'DNT': '1',
    'Sec-GPC': '1',
    # Requests doesn't support trailers
    # 'TE': 'trailers',
}

pages = list(range(1,10))

print(pages)

for page in pages:
    
    keep_going = True
    page = 0
    while keep_going:
        page = page+1
        params = {
            'type': 'color',
            'query': 'purple',
            'locale': 'en-us',
            'searchType': 'suggest.json',
            'pageNo': str(page),
            'maxResult': '100',
        }
    
        r = requests.get('https://api.benjaminmoore.io/service/search', params=params, headers=headers)
        
        df = pd.DataFrame(r.json()['records']['page'])
        df = df[df['type']=='Color']
        
        if df.shape[0] != 0:
            df.to_csv(f'data/created/bmoore_purple_pg{str(page)}.csv', index=False)
        else:
            break
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
# search for gray

headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:126.0) Gecko/20100101 Firefox/126.0',
    'Accept': 'application/json, text/plain, */*',
    'Accept-Language': 'en-US,en;q=0.5',
    # 'Accept-Encoding': 'gzip, deflate, br, zstd',
    'Ocp-Apim-Subscription-Key': '48c3c3e75b424f97904f9659da65b4d0',
    'Origin': 'https://www.benjaminmoore.com',
    'Connection': 'keep-alive',
    'Referer': 'https://www.benjaminmoore.com/',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'cross-site',
    'DNT': '1',
    'Sec-GPC': '1',
    # Requests doesn't support trailers
    # 'TE': 'trailers',
}

pages = list(range(1,10))

print(pages)

for page in pages:
    
    keep_going = True
    page = 0
    while keep_going:
        page = page+1
        params = {
            'type': 'color',
            'query': 'gray',
            'locale': 'en-us',
            'searchType': 'suggest.json',
            'pageNo': str(page),
            'maxResult': '100',
        }
    
        r = requests.get('https://api.benjaminmoore.io/service/search', params=params, headers=headers)
        
        df = pd.DataFrame(r.json()['records']['page'])
        df = df[df['type']=='Color']
        
        if df.shape[0] != 0:
            df.to_csv(f'data/created/bmoore_gray_pg{str(page)}.csv', index=False)
        else:
            break
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
# search for neutral

headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:126.0) Gecko/20100101 Firefox/126.0',
    'Accept': 'application/json, text/plain, */*',
    'Accept-Language': 'en-US,en;q=0.5',
    # 'Accept-Encoding': 'gzip, deflate, br, zstd',
    'Ocp-Apim-Subscription-Key': '48c3c3e75b424f97904f9659da65b4d0',
    'Origin': 'https://www.benjaminmoore.com',
    'Connection': 'keep-alive',
    'Referer': 'https://www.benjaminmoore.com/',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'cross-site',
    'DNT': '1',
    'Sec-GPC': '1',
    # Requests doesn't support trailers
    # 'TE': 'trailers',
}

pages = list(range(1,10))

print(pages)

for page in pages:
    
    keep_going = True
    page = 0
    while keep_going:
        page = page+1
        params = {
            'type': 'color',
            'query': 'neutral',
            'locale': 'en-us',
            'searchType': 'suggest.json',
            'pageNo': str(page),
            'maxResult': '100',
        }
    
        r = requests.get('https://api.benjaminmoore.io/service/search', params=params, headers=headers)
        
        df = pd.DataFrame(r.json()['records']['page'])
        df = df[df['type']=='Color']
        
        if df.shape[0] != 0:
            df.to_csv(f'data/created/bmoore_neutral_pg{str(page)}.csv', index=False)
        else:
            break

# This breaks on page 5
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 43
#      40 r = requests.get('https://api.benjaminmoore.io/service/search', params=params, headers=headers)
#      42 df = pd.DataFrame(r.json()['records']['page'])
# ---> 43 df = df[df['type']=='Color']
#      45 if df.shape[0] != 0:
#      46     df.to_csv(f'data/created/bmoore_neutral_pg{str(page)}.csv', index=False)
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/pandas/core/indexes/range.py:417, in RangeIndex.get_loc(self, key)
# ...

# %%
# search for white

headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:126.0) Gecko/20100101 Firefox/126.0',
    'Accept': 'application/json, text/plain, */*',
    'Accept-Language': 'en-US,en;q=0.5',
    # 'Accept-Encoding': 'gzip, deflate, br, zstd',
    'Ocp-Apim-Subscription-Key': '48c3c3e75b424f97904f9659da65b4d0',
    'Origin': 'https://www.benjaminmoore.com',
    'Connection': 'keep-alive',
    'Referer': 'https://www.benjaminmoore.com/',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'cross-site',
    'DNT': '1',
    'Sec-GPC': '1',
    # Requests doesn't support trailers
    # 'TE': 'trailers',
}

pages = list(range(1,10))

print(pages)

for page in pages:
    
    keep_going = True
    page = 0
    while keep_going:
        page = page+1
        params = {
            'type': 'color',
            'query': 'white',
            'locale': 'en-us',
            'searchType': 'suggest.json',
            'pageNo': str(page),
            'maxResult': '100',
        }
    
        r = requests.get('https://api.benjaminmoore.io/service/search', params=params, headers=headers)
        
        df = pd.DataFrame(r.json()['records']['page'])
        df = df[df['type']=='Color']
        
        if df.shape[0] != 0:
            df.to_csv(f'data/created/bmoore_white_pg{str(page)}.csv', index=False)
        else:
            break
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
# search for off-white (not it's own color family, but was curious if this would return more)

headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:126.0) Gecko/20100101 Firefox/126.0',
    'Accept': 'application/json, text/plain, */*',
    'Accept-Language': 'en-US,en;q=0.5',
    # 'Accept-Encoding': 'gzip, deflate, br, zstd',
    'Ocp-Apim-Subscription-Key': '48c3c3e75b424f97904f9659da65b4d0',
    'Origin': 'https://www.benjaminmoore.com',
    'Connection': 'keep-alive',
    'Referer': 'https://www.benjaminmoore.com/',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'cross-site',
    'DNT': '1',
    'Sec-GPC': '1',
    # Requests doesn't support trailers
    # 'TE': 'trailers',
}

pages = list(range(1,10))

print(pages)

for page in pages:
    
    keep_going = True
    page = 0
    while keep_going:
        page = page+1
        params = {
            'type': 'color',
            'query': 'off-white',
            'locale': 'en-us',
            'searchType': 'suggest.json',
            'pageNo': str(page),
            'maxResult': '100',
        }
    
        r = requests.get('https://api.benjaminmoore.io/service/search', params=params, headers=headers)
        
        df = pd.DataFrame(r.json()['records']['page'])
        df = df[df['type']=='Color']
        
        if df.shape[0] != 0:
            df.to_csv(f'data/created/bmoore_off-white_pg{str(page)}.csv', index=False)
        else:
            break

# Like neutral, off white breaks on p3
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 43
#      40 r = requests.get('https://api.benjaminmoore.io/service/search', params=params, headers=headers)
#      42 df = pd.DataFrame(r.json()['records']['page'])
# ---> 43 df = df[df['type']=='Color']
#      45 if df.shape[0] != 0:
#      46     df.to_csv(f'data/created/bmoore_off-white_pg{str(page)}.csv', index=False)
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/pandas/core/indexes/range.py:417, in RangeIndex.get_loc(self, key)
# ...

# %% [markdown]
# # Using scraped paint names to get remaining paint colors
# I have my code above, but now I need to take my list of the 2674 missing colors and run that through the API and rewrite the API code to just pull the first result into df. Prob just use the API and sleep? But I would need to change output from csv to append to df and to only grab first result

# %%
color_names = pd.read_csv('missing_colors.csv')
color_names
# Out:
#       Unnamed: 0        color_name
# 0              0     Easter Bonnet
# 1              1   Bunny Nose Pink
# 2              2    Exotic Fuchsia
# 3              3        Lilac Pink
# 4              4  Twilight Magenta
# ...          ...               ...
# 2559        2559       Celtic Blue
# 2560        2560      Del Mar Blue
# 2561        2561     Piedmont Gray
# 2562        2562     Bleached Gray
# 2563        2563   Georgetown Gray
#
# [2564 rows x 2 columns]

# %%
color_name = color_names['color_name']
color_name
# Out:
# 0          Easter Bonnet
# 1        Bunny Nose Pink
# 2         Exotic Fuchsia
# 3             Lilac Pink
# 4       Twilight Magenta
#               ...
# 2559         Celtic Blue
# 2560        Del Mar Blue
# 2561       Piedmont Gray
# 2562       Bleached Gray
# 2563     Georgetown Gray
# Name: color_name, Length: 2564, dtype: object

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:126.0) Gecko/20100101 Firefox/126.0',
    'Accept': 'application/json, text/plain, */*',
    'Accept-Language': 'en-US,en;q=0.5',
    # 'Accept-Encoding': 'gzip, deflate, br, zstd',
    'Ocp-Apim-Subscription-Key': '48c3c3e75b424f97904f9659da65b4d0',
    'Origin': 'https://www.benjaminmoore.com',
    'Connection': 'keep-alive',
    'Referer': 'https://www.benjaminmoore.com/',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'cross-site',
    'DNT': '1',
    'Sec-GPC': '1',
    # Requests doesn't support trailers
    # 'TE': 'trailers',
}

full_df = pd.DataFrame()

# testing with limited list
for name in color_name[:10]:
    params = {
        'type': 'color',
        'query': name,
        'locale': 'en-us',
        'searchType': 'suggest.json',
        'pageNo': '1',
        'maxResult': '1',
    }
    
    r = requests.get('https://api.benjaminmoore.io/service/search', params=params, headers=headers)
    results_df = pd.DataFrame(r.json()['records']['page'])
    full_df = pd.concat([full_df, results_df], ignore_index=True)
    time.sleep(1)

full_df
# Out:
#                                             sections  \
# 0  [Easter Bonnet, Matching Colors, Different Sha...
# 1  [Bunny Nose Pink, Matching Colors, Different S...
# 2  [Exotic Fuchsia, Matching Colors, Different Sh...
# 3  [Lilac Pink, Matching Colors, Different Shades...
# 4  [Twilight Magenta, Matching Colors, Different ...
# 5  [Summer Plum, Matching Colors, Different Shade...
# 6  [Elderberry Wine, Matching Colors, Different S...
# 7  [Charming Pink, Matching Colors, Different Sha...
# 8  [Passion Pink, Matching Colors, Different Shad...
# 9  [Pink Taffy, Matching Colors, Different Shades...
#
#                                            page_path  \
# 0    /en-us/paint-colors/color/2074-70/easter-bonnet
# 1  /en-us/paint-colors/color/2074-60/bunny-nose-pink
# 2   /en-us/paint-colors/color/2074-50/exotic-fuchsia
# 3       /en-us/paint-colors/color/2074-40/lilac-pink
# 4  /en-us/paint-colors/color/2074-30/twilight-mag...
# 5      /en-us/paint-colors/color/2074-20/summer-plum
# ...

# %%
# full query for over 2,000 paint names, getting just first result of each

headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:126.0) Gecko/20100101 Firefox/126.0',
    'Accept': 'application/json, text/plain, */*',
    'Accept-Language': 'en-US,en;q=0.5',
    # 'Accept-Encoding': 'gzip, deflate, br, zstd',
    'Ocp-Apim-Subscription-Key': '48c3c3e75b424f97904f9659da65b4d0',
    'Origin': 'https://www.benjaminmoore.com',
    'Connection': 'keep-alive',
    'Referer': 'https://www.benjaminmoore.com/',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'cross-site',
    'DNT': '1',
    'Sec-GPC': '1',
    # Requests doesn't support trailers
    # 'TE': 'trailers',
}

full_df = pd.DataFrame()
# make an empty df

for name in color_name:

    params = {
        'type': 'color',
        'query': name,
        'locale': 'en-us',
        'searchType': 'suggest.json',
        'pageNo': '1',
        'maxResult': '1',
    }
    
    r = requests.get('https://api.benjaminmoore.io/service/search', params=params, headers=headers)
    results_df = pd.DataFrame(r.json()['records']['page'])
    full_df = pd.concat([full_df, results_df], ignore_index=True)
    time.sleep(1)

full_df
# Out:
#                                                sections  \
# 0     [Easter Bonnet, Matching Colors, Different Sha...
# 1     [Bunny Nose Pink, Matching Colors, Different S...
# 2     [Exotic Fuchsia, Matching Colors, Different Sh...
# 3     [Lilac Pink, Matching Colors, Different Shades...
# 4     [Twilight Magenta, Matching Colors, Different ...
# ...                                                 ...
# 2559  [Celtic Blue, Discover This Color in Woodluxe ...
# 2560  [Del Mar Blue, Matching Colors, Different Shad...
# 2561  [Piedmont Gray, Matching Colors, Similar Color...
# 2562  [Bleached Gray, Discover This Color in Woodlux...
# 2563  [Georgetown Gray, Discover This Color in Woodl...
#
#                                               page_path  \
# 0       /en-us/paint-colors/color/2074-70/easter-bonnet
# 1     /en-us/paint-colors/color/2074-60/bunny-nose-pink
# 2      /en-us/paint-colors/color/2074-50/exotic-fuchsia
# 3          /en-us/paint-colors/color/2074-40/lilac-pink
# ...

# %% [markdown]
# This worked. First and last rows look right, next step to combine with the original scraper rows and then check for/remove duplicates.

# %%
full_df.to_csv('additional_colors.csv', index=False)
